# %% [markdown]
# ## Домашнее задание №1

# %% [markdown]
# ### Вопрос №1

# %% [markdown]
# 1. Исследовать на линейную зависимость:
#
# 𝑓1(𝑥)=𝑒𝑥,𝑓2(𝑥)=1,𝑓3(𝑥)=𝑥+1,𝑓4(𝑥)=𝑥−𝑒𝑥.

# %% [markdown]
# ### Ответ №1

# %% [markdown]
# ![photo_2021-07-19%2000.34.50.jpeg](attachment:photo_2021-07-19%2000.34.50.jpeg)

# %% [markdown]
# ### Вопрос №2

# %% [markdown]
# Исследовать на линейную зависимость:
# 𝑓1(𝑥)=2,𝑓2(𝑥)=𝑥,𝑓3(𝑥)=𝑥2,𝑓4(𝑥)=(𝑥+1)2

# %% [markdown]
# ### Ответ №2

# %% [markdown]
# ![photo_2021-07-19%2000.34.53.jpeg](attachment:photo_2021-07-19%2000.34.53.jpeg)

# %% [markdown]
# ### Вопрос №3

# %% [markdown]
# Найти координаты вектора  𝑥=(2,3,5)∈ℝ3  в базисе  𝑏1=(0,0,10) ,  𝑏2=(2,0,0) ,  𝑏3=(0,1,0) .

# %% [markdown]
# ### Ответ №3

# %% [markdown]
# ![photo_2021-07-19%2000.34.55.jpeg](attachment:photo_2021-07-19%2000.34.55.jpeg)

# %% [markdown]
# ### Вопрос №4

# %% [markdown]
# Найти координаты вектора  3𝑥2−2𝑥+2∈ℝ3[𝑥] :\
# а) в базисе  1 ,  𝑥 ,  𝑥2 ;\
# б) в базисе  𝑥2 ,  𝑥−1 ,  1 .

# %% [markdown]
# ### Ответ №4

# %% [markdown]
# ![photo_2021-07-19%2000.34.58.jpeg](attachment:photo_2021-07-19%2000.34.58.jpeg)
